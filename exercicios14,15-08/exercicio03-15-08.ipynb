# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
caminho_arquivo = (r'C:\Users\andre_r_borges\Downloads\correcao_bugs.xlsx')
df_bug = pd.read_excel (caminho_arquivo)

# %%
df_bug
# Out:
#               Localização do Bug Sistema Operacional  Versão do Software  \
# 0                       Frontend             Windows                 1.0
# 1                        Backend               Linux                 1.0
# 2                 Banco de Dados             Windows                 2.0
# 3           Integrações Externas               Linux                 1.0
# 4       Configuração do Ambiente             Windows                 1.0
# 5                      Segurança               Linux                 2.0
# 6                    Performance             Windows                 1.0
# 7                          UI/UX               Linux                 1.0
# 8   Compatibilidade de Navegador             Windows                 2.0
# 9                         Mobile               Linux                 1.0
# 10                      Frontend             Windows                 2.0
# 11                       Backend               Linux                 2.0
# ...

# %%
df_bug['Classificação de Bug']
mapeamento_classificacao_bug = {'Crítico': 0,'Importante': 1, 'Baixo': 2, 'Cosmético': 3, 'Moderado': 4}

# %%
df_bug['Classificação de Bug'] = df_bug['Classificação de Bug'].map(mapeamento_classificacao_bug)
df_bug
# Out:
#               Localização do Bug Sistema Operacional  Versão do Software  \
# 0                       Frontend             Windows                 1.0
# 1                        Backend               Linux                 1.0
# 2                 Banco de Dados             Windows                 2.0
# 3           Integrações Externas               Linux                 1.0
# 4       Configuração do Ambiente             Windows                 1.0
# 5                      Segurança               Linux                 2.0
# 6                    Performance             Windows                 1.0
# 7                          UI/UX               Linux                 1.0
# 8   Compatibilidade de Navegador             Windows                 2.0
# 9                         Mobile               Linux                 1.0
# 10                      Frontend             Windows                 2.0
# 11                       Backend               Linux                 2.0
# ...
